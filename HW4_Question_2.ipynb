# %%
import random
import timeit
import matplotlib.pyplot as plt

# %%
#Merge Sort implementation from https://www.geeksforgeeks.org/python-program-for-merge-sort/

def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
        
    
    
#insertio sort implementation from https://www.geeksforgeeks.org/python-program-for-insertion-sort/
def insertionSort(arr):
 
    # Traverse through 1 to len(arr)
    for i in range(1, len(arr)):
 
        key = arr[i]
 
        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key
        
def mergeSort_for_tim(arr, l, r,k=75):
    if l < r:

    # Same as (l+r)//2, but avoids overflow for
    # large l and h
        m = l+(r-l)//2

        # Sort first and second halves
        if m <= k:
            insertionSort(arr[l:m])
            insertionSort(arr[m+1:r])
            merge(arr,l,m,r)
        else:
            mergeSort_for_tim(arr, l, m)
            mergeSort_for_tim(arr, m+1, r)
        
def timSort(arr, l,r,k=75):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2

        if m <= k:
            insertionSort(arr[l:m])
            insertionSort(arr[m+1:r])
            merge(arr,l,m,r)
        else:
            mergeSort_for_tim(arr, l, m)
            mergeSort_for_tim(arr, m+1, r)

# %%
len_10_set_up = '''
rand_list=[]
max_num = 100000
n = 10
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''


len_50_set_up = '''
rand_list=[]
max_num = 100000
n = 50
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_75_set_up = '''
rand_list=[]
max_num = 100000
n = 75
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''


len_100_set_up = '''
rand_list=[]
max_num = 100000
n = 100
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_150_set_up = '''
rand_list=[]
max_num = 100000
n = 150
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''


len_250_set_up = '''
rand_list=[]
max_num = 100000
n = 250
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_500_set_up = '''
rand_list=[]
max_num = 100000
n = 500
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_1000_set_up = '''
rand_list=[]
max_num = 100000
n = 1000
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_2000_set_up = '''
rand_list=[]
max_num = 100000
n = 2000
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_5000_set_up = '''
rand_list=[]
max_num = 100000
n = 5000
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''


merge_sort = '''
    mergeSort(rand_list, 0, len(rand_list)-1)
'''
    
insertion_sort  = '''
    insertionSort(rand_list)
'''

tim_sort_75  = '''
    timSort(rand_list, 0, len(rand_list)-1, k=75)
'''

tim_sort_50  = '''
    timSort(rand_list, 0, len(rand_list)-1, k=50)
'''

tim_sort_60  = '''
    timSort(rand_list, 0, len(rand_list)-1, k=60)
'''

tim_sort_100  = '''
    timSort(rand_list, 0, len(rand_list)-1, k=100)
'''

# %%
#q1 
diff_lengths = [len_10_set_up, len_50_set_up, len_75_set_up,
                len_100_set_up, len_150_set_up,len_250_set_up,len_500_set_up
               ,len_1000_set_up,len_2000_set_up, len_5000_set_up]

merge_avg_time = []

insertion_avg_time = []

tim_50_time = []
tim_60_time = []
tim_75_time = []
tim_100_time = []

for i in range(len(diff_lengths)):
    time = 0
    
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = merge_sort,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    merge_avg_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = insertion_sort,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    insertion_avg_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_50,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_50_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_60,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_60_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_75,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_75_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_100,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_100_time.append(time/100)
ns = [10,50,75,100,150,250,500,1000,2000,5000]

#plt.plot(ns, merge_avg_time, label='merge')
#plt.plot(ns, insertion_avg_time, label='insertion')
plt.plot(ns, tim_50_time, label='tim_50')
plt.plot(ns, tim_60_time, label='tim_60')
plt.plot(ns, tim_75_time, label='tim_75')
plt.plot(ns, tim_100_time, label='tim_100')
plt.ylabel('Time Taken for one iteration')
plt.xlabel('Number of elements in unsorted list')
plt.title("Number of elements in unsorted list versus time taken to sort")
plt.legend()

# %%
#q1 
diff_lengths = [len_10_set_up, len_50_set_up, len_75_set_up,
                len_100_set_up, len_150_set_up,len_250_set_up,len_500_set_up]

merge_avg_time = []

insertion_avg_time = []

tim_75_time = []

for i in range(len(diff_lengths)):
    time = 0
    
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = merge_sort,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    merge_avg_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = insertion_sort,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    insertion_avg_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_75,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_75_time.append(time/100)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = tim_sort_60,
                     number = 1,
                     repeat=100,
                     globals=globals()))
    tim_60_time.append(time/100)

ns = [10,50,75,100,150,250,500]

plt.plot(ns, merge_avg_time, label='merge')
plt.plot(ns, insertion_avg_time, label='insertion')
plt.plot(ns, tim_75_time, label='tim_75')
plt.ylabel('Time Taken for one iteration')
plt.xlabel('Number of elements in unsorted list')
plt.title("Number of elements in unsorted list versus time taken to sort")
plt.legend()
