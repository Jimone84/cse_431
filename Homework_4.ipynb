# %%
import random
import timeit
import matplotlib.pyplot as plt

# %%
#Merge Sort implementation from https://www.geeksforgeeks.org/python-program-for-merge-sort/

def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
        
    
    
#insertio sort implementation from https://www.geeksforgeeks.org/python-program-for-insertion-sort/
def insertionSort(arr):
 
    # Traverse through 1 to len(arr)
    for i in range(1, len(arr)):
 
        key = arr[i]
 
        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key

# %%
len_10_set_up = '''
rand_list=[]
max_num = 100000
n = 10
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_50_set_up = '''
rand_list=[]
max_num = 100000
n = 50
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_75_set_up = '''
rand_list=[]
max_num = 100000
n = 75
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_100_set_up = '''
rand_list=[]
max_num = 100000
n = 100
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_125_set_up = '''
rand_list=[]
max_num = 100000
n = 125
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_150_set_up = '''
rand_list=[]
max_num = 100000
n = 150
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_175_set_up = '''
rand_list=[]
max_num = 100000
n = 175
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_200_set_up = '''
rand_list=[]
max_num = 100000
n = 200
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''

len_250_set_up = '''
rand_list=[]
max_num = 100000
n = 250
for i in range(n):
    rand_list.append(random.randint(0,max_num))
'''
merge_sort = '''
    mergeSort(rand_list, 0, len(rand_list)-1)
'''
    
insertion_sort  = '''
    insertionSort(rand_list)
'''

# %%
#q1 
diff_lengths = [len_10_set_up,len_50_set_up,len_75_set_up,len_100_set_up,len_125_set_up,
                len_150_set_up,len_175_set_up,len_200_set_up,len_250_set_up]

merge_avg_time = []

insertion_avg_time = []

for i in range(len(diff_lengths)):
    time = 0
    
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = merge_sort,
                     number = 1,
                     repeat=1000,
                     globals=globals()))
    merge_avg_time.append(time/1000)
    
    time = 0
    time = sum(timeit.repeat(setup = diff_lengths[i],
                     stmt = insertion_sort,
                     number = 1,
                     repeat=1000,
                     globals=globals()))
    insertion_avg_time.append(time/1000)
    
ns = [10,50,75,100,125,150,175,200,250]

plt.plot(ns, merge_avg_time, label='merge')
plt.plot(ns, insertion_avg_time, label='insertion')
plt.ylabel('Time Taken for one iteration')
plt.xlabel('Number of elements in unsorted list')
plt.title("Number of elements in unsorted list versus time taken to sort")
plt.legend()
plt.savefig('HW4_Q1.png')
